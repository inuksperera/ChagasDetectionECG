# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install einops==0.8.0 h5py==3.11.0 matplotlib==3.8.4 numpy==2.0.2 pandas==2.2.2 PyYAML==6.0.2 scikit_learn==1.6.1 scipy==1.16.3 seaborn==0.13.2 timm==1.0.8 torchmetrics==1.4.0.post0 tqdm==4.67.1 wfdb==4.1.2
# %cd /content/drive/MyDrive/ChagasDetectionECG
# Out:
# Mounted at /content/drive
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 69.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 111.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 44.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 83.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 45.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.0/160.0 kB 13.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.3
#     Uninstalling PyYAML-6.0.3:
#       Successfully uninstalled PyYAML-6.0.3
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.15.1
#     Uninstalling h5py-3.15.1:
#       Successfully uninstalled h5py-3.15.1
# ...

# %%
# %cd /content/drive/MyDrive/ChagasDetectionECG
# Out:
# /content/drive/Othercomputers/My Laptop/ChagasDetectionECG

# %%
# !pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %% [markdown]
# # Pretraining code

# %%
# !python pretrain_ECG_JEPA.py --mask_type random --mask_scale 0.6 0.7 --epochs 1 --batch_size 50 --lr 2.5e-5 --data_dir_shao "/content/drive/MyDrive/fyp_data/chapman-test-half/WFDBRecords" --data_dir_code15 "/content/drive/MyDrive/fyp_data/code-15/4916206/exams_part0"
# Out:
# Processing record: JS00154
# Processing record: JS00181
# Processing record: JS00140
# Processing record: JS00139
# Processing record: JS00130
# Processing record: JS00159
# Processing record: JS00146
# Processing record: JS00184
# Processing record: JS00153
# Processing record: JS00169
# Processing record: JS00196
# Processing record: JS00165
# Processing record: JS00127
# Processing record: JS00170
# Processing record: JS00166
# Processing record: JS00190
# Processing record: JS00107
# Processing record: JS00185
# Processing record: JS00114
# Processing record: JS00156
# Processing record: JS00143
# Processing record: JS00155
# Processing record: JS00167
# Processing record: JS00195
# Processing record: JS00203
# Processing record: JS00186
# Processing record: JS00132
# Processing record: JS00158
# Processing record: JS00152
# Processing record: JS00204
# Processing record: JS00134
# Processing record: JS00173
# Processing record: JS00122
# Processing record: JS00189
# ...

# %%
import os

path_to_check = "/content/drive/MyDrive/fyp_data/code-15/4916206/"

if os.path.exists(path_to_check):
    print(f"Path exists: {path_to_check}")
    print("Contents:", os.listdir(path_to_check))  # shows files inside
else:
    print(f"Path does NOT exist or is inaccessible: {path_to_check}")
# Out:
# Path exists: /content/drive/MyDrive/fyp_data/code-15/4916206/
# Contents: ['exams_part0']

# %%
from torch.cuda.amp import GradScaler, autocast

scaler = GradScaler()
# Out:
# /tmp/ipython-input-2092207722.py:3: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()

# %% [markdown]
# # Pretraining Checkpoint

# %%
import numpy as np
import torch
from models import load_encoder
import os
# Load the encoder
ckpt_dir = '/content/drive/MyDrive/fyp_data/weight_ckpt/random_epoch100.pth'  # See https://github.com/sehunfromdaegu/ECG_JEPA for checkpoint download link
encoder, dim = load_encoder(ckpt_dir=ckpt_dir) # dim is the dimension of the latent space


# path_to_check = "/content/drive/MyDrive/fyp_data/weight_ckpt"

# if os.path.exists(path_to_check):
#     print(f"Path exists: {path_to_check}")
#     print("Contents:", os.listdir(path_to_check))  # shows files inside
# else:
#     print(f"Path does NOT exist or is inaccessible: {path_to_check}")

# %% [markdown]
# # Downstreaming

# %%
# %cd downstream_tasks
# Out:
# /content/drive/Othercomputers/My Laptop/ChagasDetectionECG/downstream_tasks

# %%
# !python linear_eval.py --ckpt_dir ckpt_dir --dataset ptbxl --data_dir '/content/drive/MyDrive/fyp_data/ptb-xl-2/' --task multilabel
# Out:
# Loading ptbxl dataset...
# ...
# Loading PTB-XL data at 500Hz from /content/drive/MyDrive/fyp_data/ptb-xl-2/...
#   3% 752/21799 [09:58<4:39:09,  1.26it/s]
# Traceback (most recent call last):
#   File "/content/drive/Othercomputers/My Laptop/ChagasDetectionECG/downstream_tasks/linear_eval.py", line 187, in <module>
#     main(config)
#   File "/content/drive/Othercomputers/My Laptop/ChagasDetectionECG/downstream_tasks/linear_eval.py", line 102, in main
#     waves_train, waves_test, labels_train, labels_test = waves_from_config(config,reduced_lead=True)
#                                                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/Othercomputers/My Laptop/ChagasDetectionECG/ecg_data.py", line 374, in waves_from_config
#     waves_train, waves_test, labels_train, labels_test = waves_ptbxl(data_dir, task, reduced_lead=reduced_lead)
# ...
