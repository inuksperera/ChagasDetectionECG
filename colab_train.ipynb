# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: '/content/drive/MyDrive/FYP/ChagasDetectionECG/IMPLEMENTATION/ChagasDetectionECG'
# /content

# %%
# %cd /content/drive/MyDrive/ChagasDetectionECG
# Out:
# /content/drive/Othercomputers/My Laptop/ChagasDetectionECG

# %%
# !python pretrain_ECG_JEPA.py --mask_type random --mask_scale 0.6 0.7 --epochs 1 --batch_size 64 --lr 2.5e-5 --data_dir_shao ../dataset/chapman-test-half/WFDBRecords --data_dir_code15 ../dataset/code-15/4916206/exams_part0
# Out:
# '/content'

# %%
import os

path_to_check = "/content/drive/MyDrive/fyp_data/chapman-test-half/WFDBRecords"

if os.path.exists(path_to_check):
    print(f"Path exists: {path_to_check}")
    print("Contents:", os.listdir(path_to_check))  # shows files inside
else:
    print(f"Path does NOT exist or is inaccessible: {path_to_check}")
# Out:
# Path exists: /content/drive/MyDrive/fyp_data/chapman-test-half/WFDBRecords
# Contents: ['01', '03', '02']
